# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as mp

from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('cost-revenue-clean.csv')

# %%
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
X= DataFrame(data, columns=['production_budget_usd'])
y= DataFrame(data, columns=['worldwide_gross_usd'])

# %%
## Adjust the size of the chart
mp.figure(figsize=(10,6))
## Call the Scatterplot Functionality (Alpha sets the transparency of the dots)
mp.scatter(X,y, alpha = 0.3)
## Add a title
mp.title('Film Cost vs Global Revenue')
## Add a label to the x-axis
mp.xlabel('Production Budget $')
## Add a label to the y-axis
mp.ylabel('Worldwide Gross $')
## Set value limits to clean the visualization on y-axis
mp.ylim(0, 3000000000)
## Set value limits to clean the visualization on the x-axis
mp.xlim(0, 450000000)
## Show the scatterplot
mp.show()

# %%
regression = LinearRegression()
regression.fit(X, y)
# Out:
# LinearRegression()

# %%
## Theta_1
regression.coef_
print('Theta1 : ', regression.coef_[0][0])
# Out:
# Theta1 :  3.1115091829361368

# %%
## Intercept
regression.intercept_
print('Intercept: ', regression.intercept_[0])
# Out:
# Intercept:  -7236192.729139909

# %%
## Render output as part of the notebook
# %matplotlib inline

## Adjust the size of the chart
mp.figure(figsize=(10,6))
## Call the Scatterplot Functionality (Alpha sets the transparency of the dots)
mp.scatter(X,y, alpha = 0.3)
## Plot Regression Model Prediction
mp.plot(X, regression.predict(X), color='red')
## Add a title
mp.title('Film Cost vs Global Revenue')
## Add a label to the x-axis
mp.xlabel('Production Budget $')
## Add a label to the y-axis
mp.ylabel('Worldwide Gross $')
## Set value limits to clean the visualization on y-axis
mp.ylim(0, 3000000000)
## Set value limits to clean the visualization on the x-axis
mp.xlim(0, 450000000)
## Style Chart
mp.style.use('fivethirtyeight')
## Show the scatterplot
mp.show()

# %%
## Amount of variation in film revenue explained by Film's budget
## Returing r-squared value
regression.score(X,y)
print('R-Square: ', regression.score(X,y))
# Out:
# R-Square:  0.5496485356985727
